# %%
# !pip install experta
from random import choice
from experta import *
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-df6364cfd158> in <cell line: 3>()
#       1 get_ipython().system('pip install experta')
#       2 from random import choice
# ----> 3 from experta import *
#
# /usr/local/lib/python3.10/dist-packages/experta/__init__.py in <module>
#       3 try:
#       4     from .conditionalelement import AND, OR, NOT, TEST, EXISTS, FORALL
# ----> 5     from .engine import KnowledgeEngine
#       6     from .fact import Fact, InitialFact, Field
#       7     from .fieldconstraint import L, W, P
#
# /usr/local/lib/python3.10/dist-packages/experta/engine.py in <module>
#      11
#      12 from experta.agenda import Agenda
# ---> 13 from experta.fact import InitialFact
#      14 from experta.factlist import FactList
#      15 from experta.rule import Rule
#
# /usr/local/lib/python3.10/dist-packages/experta/fact.py in <module>
# ...

# %%
class Işık(Fact):
  """Bilgi"""
  pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aee6f89bae1b> in <cell line: 1>()
# ----> 1 class Işık(Fact):
#       2   pass
#
# NameError: name 'Fact' is not defined

# %%
class KarşıdanKarşıyaGeçme(KnowledgeEngine):

  @Rule(Işık(renk="yeşil"))
  def yeşil_ışık(self):
    print("Yeşil ışık yandığı için yürüyebilirsiniz.")

  @Rule(Işık(renk="kırmızı"))
  def    kırmızı_ışık(self):
    print("Kırmızı ışık yandığı için durmalısınız.")

  @Rule(Işık(renk="sarı"))
  def sarı_ışık(self):
    print("Sarı ışık yanıyor. Lütfen dikkatli olunuz.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3a685954216b> in <cell line: 1>()
# ----> 1 class KarşıdanKarşıyaGeçme(KnowledgeEngine):
#       2
#       3   @Rule(Işık(renk="yeşil"))
#       4   def yeşil_ışık(self):
#       5     print("Yeşil ışık yandığı için yürüyebilirsiniz.")
#
# NameError: name 'KnowledgeEngine' is not defined

# %%
uzman = KarşıdanKarşıyaGeçme()
uzman.reset()
uzman.declare(Işık(renk=choice(["yeşil","sarı","kırmızı"])))
uzman.run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a91c1f20b3a8> in <cell line: 1>()
# ----> 1 uzman = KarşıdanKarşıyaGeçme()
#       2 uzman.reset()
#       3 uzman.declare(Işık(renk=choice(["yeşil","sarı","kırmızı"])))
#       4 uzman.run()
#
# NameError: name 'KarşıdanKarşıyaGeçme' is not defined
